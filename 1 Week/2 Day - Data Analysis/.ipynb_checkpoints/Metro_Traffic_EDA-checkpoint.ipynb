# %% [markdown]
# # Стань детективом данных — EDA
# ## Metro Interstate Traffic Volume
#
# **YDL 2026 · Неделя 1 · День 2 · Лабораторная**
#
# Почасовой трафик на трассе I-94 (Миннеаполис–Сент-Пол, станция ATR 301) + погода и праздники.
# Источник: Minnesota DoT + OpenWeatherMap (UCI / Kaggle).
#
# Задача дня — не учить методы, а **допрашивать данные**: на каждый ответ спрашивать «сколько строк? нет ли пропусков? число осмысленное?».
#
# Структура:
# 1. Загрузка и первый взгляд
# 2. Чистка ловушек (битые temp, выброс дождя, дубли, holiday)
# 3. Три проверенных вопроса → открытия
# 4. Разрезаем глубже
# 5. **Особый вызов: поймай враньё**
# 6. Итог: одно открытие одной фразой

# %% [markdown]
# ## 0. Импорты и загрузка

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = (10, 5)
sns.set_style('whitegrid')

df = pd.read_csv('Metro_Interstate_Traffic_Volume.csv')
print('Строк:', df.shape[0], '| Колонок:', df.shape[1])
df.head()
# Out:
# Строк: 48204 | Колонок: 9
#    traffic_volume holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0            5545     NaN  288.28      0.0      0.0          40       Clouds
# 1            4516     NaN  289.36      0.0      0.0          75       Clouds
# 2            4767     NaN  289.58      0.0      0.0          90       Clouds
# 3            5026     NaN  290.13      0.0      0.0          90       Clouds
# 4            4918     NaN  291.14      0.0      0.0          75       Clouds
#
#   weather_description         date_time
# 0    scattered clouds  02-10-2012 09:00
# 1       broken clouds  02-10-2012 10:00
# 2     overcast clouds  02-10-2012 11:00
# 3     overcast clouds  02-10-2012 12:00
# 4       broken clouds  02-10-2012 13:00

# %%
# Что внутри: типы, пропуски
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   traffic_volume       48204 non-null  int64
#  1   holiday              61 non-null     str
#  2   temp                 48204 non-null  float64
#  3   rain_1h              48204 non-null  float64
#  4   snow_1h              48204 non-null  float64
#  5   clouds_all           48204 non-null  int64
#  6   weather_main         48204 non-null  str
#  7   weather_description  48204 non-null  str
#  8   date_time            48204 non-null  str
# dtypes: float64(3), int64(2), str(4)
# memory usage: 3.3 MB

# %% [markdown]
# ### Первая проверка: пропуски
#
# `holiday` почти весь пустой — это **не ошибка**: значение проставлено только в час, когда наступает праздник.
# Если поверить «пропуск = нет данных» и удалить эти строки — потеряем половину датасета зря. Это первая ловушка.

# %%
print('Пропуски по колонкам:')
print(df.isnull().sum())
print()
print('Заполненных holiday:', df['holiday'].notna().sum(), 'из', len(df))
print('Какие праздники:', df['holiday'].dropna().unique())
# Out:
# Пропуски по колонкам:
# traffic_volume             0
# holiday                48143
# temp                       0
# rain_1h                    0
# snow_1h                    0
# clouds_all                 0
# weather_main               0
# weather_description        0
# date_time                  0
# dtype: int64
#
# Заполненных holiday: 61 из 48204
# Какие праздники: <StringArray>
# [             'Columbus Day',              'Veterans Day',
#           'Thanksgiving Day',             'Christmas Day',
#              'New Years Day',      'Washingtons Birthday',
#               'Memorial Day',          'Independence Day',
#                 'State Fair',                 'Labor Day',
#  'Martin Luther King Jr Day']
# Length: 11, dtype: str

# %% [markdown]
# ## 1. Разбираем дату/время

# %%
df['date_time'] = pd.to_datetime(df['date_time'], format='%d-%m-%Y %H:%M')
df['hour']    = df['date_time'].dt.hour
df['weekday'] = df['date_time'].dt.day_name()
df['month']   = df['date_time'].dt.month
df['year']    = df['date_time'].dt.year
df['is_weekend'] = df['date_time'].dt.weekday >= 5

print('Период:', df['date_time'].min(), '→', df['date_time'].max())
df[['date_time','hour','weekday','traffic_volume']].head()
# Out:
# Период: 2012-10-02 09:00:00 → 2018-09-30 23:00:00
#             date_time  hour  weekday  traffic_volume
# 0 2012-10-02 09:00:00     9  Tuesday            5545
# 1 2012-10-02 10:00:00    10  Tuesday            4516
# 2 2012-10-02 11:00:00    11  Tuesday            4767
# 3 2012-10-02 12:00:00    12  Tuesday            5026
# 4 2012-10-02 13:00:00    13  Tuesday            4918

# %% [markdown]
# ## 2. Чистка ловушек
#
# Прежде чем что-то считать — найдём грязь, иначе все средние будут врать.

# %% [markdown]
# ### Ловушка A: температура 0 K
# 0 кельвинов = абсолютный ноль, физически невозможно. Это битые записи сенсора.

# %%
print('Минимальная temp:', df['temp'].min(), 'K')
print('Строк с temp == 0:', (df['temp'] == 0).sum())
# Переводим в Цельсий и зануляем битые
df['temp_C'] = df['temp'] - 273.15
df.loc[df['temp'] == 0, 'temp_C'] = np.nan
print('После чистки temp_C мин/макс:', round(df['temp_C'].min(),1), '/', round(df['temp_C'].max(),1), '°C')
# Out:
# Минимальная temp: 0.0 K
# Строк с temp == 0: 10
# После чистки temp_C мин/макс: -29.8 / 36.9 °C

# %% [markdown]
# ### Ловушка B: дождь 9831 мм за час
# Мировой рекорд осадков за час ~305 мм. 9831 мм — явная опечатка/сбой.

# %%
print('Топ-5 значений rain_1h:')
print(df['rain_1h'].sort_values(ascending=False).head())
print('Строк с rain_1h > 1000:', (df['rain_1h'] > 1000).sum())
df.loc[df['rain_1h'] > 1000, 'rain_1h'] = np.nan
print('После чистки макс дождь:', df['rain_1h'].max(), 'мм')
# Out:
# Топ-5 значений rain_1h:
# 24872    9831.30
# 8247       55.63
# 7179       44.45
# 25779      31.75
# 10806      28.70
# Name: rain_1h, dtype: float64
# Строк с rain_1h > 1000: 1
# После чистки макс дождь: 55.63 мм

# %% [markdown]
# ### Ловушка C: дубликаты по времени
# Один и тот же час встречается несколько раз — часто из-за разных погодных записей на один час.
# Считать по сырым строкам = завышать веса задублированных часов.

# %%
dups = df['date_time'].duplicated().sum()
print('Дублирующихся меток времени:', dups)
# Пример задвоенного часа
ex = df[df['date_time'].duplicated(keep=False)].sort_values('date_time')
ex[['date_time','traffic_volume','weather_main','weather_description']].head(6)
# Out:
# Дублирующихся меток времени: 7629
#               date_time  traffic_volume weather_main      weather_description
# 178 2012-10-10 07:00:00            6793         Rain               light rain
# 179 2012-10-10 07:00:00            6793      Drizzle  light intensity drizzle
# 180 2012-10-10 08:00:00            6283         Rain               light rain
# 181 2012-10-10 08:00:00            6283      Drizzle  light intensity drizzle
# 182 2012-10-10 09:00:00            5680         Rain               light rain
# 183 2012-10-10 09:00:00            5680      Drizzle  light intensity drizzle

# %%
# Оставляем одну запись на час (первую). traffic_volume на дубль-часах обычно совпадает.
df_clean = df.drop_duplicates(subset='date_time', keep='first').copy()
print('Было строк:', len(df), '| Стало:', len(df_clean))
# Out:
# Было строк: 48204 | Стало: 40575

# %% [markdown]
# ## 3. Три проверенных вопроса
#
# Не «покажи groupby», а то, что реально любопытно про трафик.

# %% [markdown]
# ### Вопрос 1: В какие часы дороги стоят, а когда пусто?

# %%
by_hour = df_clean.groupby('hour')['traffic_volume'].agg(['mean','count'])
print(by_hour.round(0))

plt.figure()
plt.plot(by_hour.index, by_hour['mean'], marker='o')
plt.title('Средний трафик по часам суток')
plt.xlabel('Час'); plt.ylabel('Машин/час'); plt.xticks(range(0,24))
plt.show()

peak = by_hour['mean'].idxmax(); low = by_hour['mean'].idxmin()
print(f'Проверка: пик в {peak}:00 ({by_hour.loc[peak,"mean"]:.0f}), минимум в {low}:00 ({by_hour.loc[low,"mean"]:.0f})')
print('Строк в каждой группе достаточно (min count):', int(by_hour['count'].min()))
# Out:
#         mean  count
# hour
# 0      845.0   1723
# 1      521.0   1710
# 2      393.0   1697
# 3      373.0   1669
# 4      701.0   1703
# 5     2104.0   1685
# 6     4172.0   1683
# 7     4770.0   1672
# 8     4594.0   1689
# 9     4395.0   1639
# 10    4205.0   1705
# 11    4498.0   1667
# 12    4739.0   1692
# 13    4742.0   1673
# 14    4957.0   1697
# 15    5272.0   1663
# 16    5709.0   1707
# 17    5351.0   1664
# 18    4306.0   1682
# 19    3311.0   1683
# 20    2870.0   1709
# 21    2699.0   1704
# 22    2224.0   1719
# 23    1491.0   1740
# Проверка: пик в 16:00 (5709), минимум в 3:00 (373)
# Строк в каждой группе достаточно (min count): 1639

# %% [markdown]
# **Открытие 1:** трафик имеет два пика — утренний и вечерний час пик, ночью (3–4 ч) дорога почти пуста.
# *Проверка:* в каждой часовой группе тысячи наблюдений — не случайность.

# %% [markdown]
# ### Вопрос 2: Будни vs выходные — разница есть и насколько?

# %%
wk = df_clean.groupby('is_weekend')['traffic_volume'].agg(['mean','count'])
wk.index = ['Будни','Выходные']
print(wk.round(0))
diff = (wk.loc['Будни','mean'] - wk.loc['Выходные','mean']) / wk.loc['Выходные','mean'] * 100
print(f'Проверка (точное число): в будни трафик на {diff:.1f}% выше, чем в выходные')
# Out:
#             mean  count
# Будни     3557.0  28979
# Выходные  2624.0  11596
# Проверка (точное число): в будни трафик на 35.6% выше, чем в выходные

# %% [markdown]
# **Открытие 2:** в будни средний трафик заметно выше выходных — считаем точный процент, а не «больше».

# %% [markdown]
# ### Вопрос 3: Снег реально снижает трафик?

# %%
snow_flag = df_clean['weather_main'] == 'Snow'
comp = df_clean.groupby(snow_flag)['traffic_volume'].agg(['mean','count'])
comp.index = ['Без снега','Снег']
print(comp.round(0))
print()
print('ПРОВЕРКА: на снег приходится только', int(comp.loc['Снег','count']),
      'строк из', len(df_clean), f'({comp.loc["Снег","count"]/len(df_clean)*100:.1f}%)')
print('Вывод про снег надо делать осторожно — выборка маленькая.')
# Out:
#              mean  count
# Без снега  3308.0  38278
# Снег       3002.0   2297
#
# ПРОВЕРКА: на снег приходится только 2297 строк из 40575 (5.7%)
# Вывод про снег надо делать осторожно — выборка маленькая.

# %% [markdown]
# **Открытие 3:** при снеге средний трафик ниже — но группа «Снег» мала, поэтому это сигнал, а не доказательство.

# %% [markdown]
# ## 4. Разрезаем глубже
#
# Профиль часа отдельно для будней и выходных — закономерность переворачивается?

# %%
piv = df_clean.pivot_table(index='hour', columns='is_weekend',
                           values='traffic_volume', aggfunc='mean')
piv.columns = ['Будни','Выходные']
plt.figure()
plt.plot(piv.index, piv['Будни'], marker='o', label='Будни')
plt.plot(piv.index, piv['Выходные'], marker='s', label='Выходные')
plt.title('Трафик по часам: будни vs выходные')
plt.xlabel('Час'); plt.ylabel('Машин/час'); plt.legend(); plt.xticks(range(0,24))
plt.show()
print('В будни два острых пика (7-8 и 16-17 ч). В выходные кривая плоская, пик сдвинут к полудню.')
# Out:
# В будни два острых пика (7-8 и 16-17 ч). В выходные кривая плоская, пик сдвинут к полудню.

# %% [markdown]
# ## 5. 🔍 Особый вызов: поймай враньё
#
# Найдём вывод, который выглядит убедительно, но разваливается при проверке.

# %% [markdown]
# ### Ловушка: «В среднем во время дождя на дорогах пусто»
#
# Наивный подход — взять среднюю температуру/трафик без чистки. Покажем, как **битые нули и выброс дождя** искажают средние.

# %%
# ВРАНЬЁ: средняя температура по сырым данным (с нулями в Кельвинах)
fake_temp = (df['temp'].mean()) - 273.15
# ПРАВДА: после удаления 10 битых нулей
true_temp = df['temp_C'].mean()
print(f'Среднее temp ПО СЫРЫМ данным:  {fake_temp:.2f} °C  (тянут вниз 10 нулей)')
print(f'Среднее temp ПОСЛЕ чистки:     {true_temp:.2f} °C')
print(f'Разница из-за 10 строк из 48000: {true_temp - fake_temp:.2f} °C')
print()
print('Всего 10 битых строк сдвигают среднюю температуру — классическое "среднее врёт".')
# Out:
# Среднее temp ПО СЫРЫМ данным:  8.06 °C  (тянут вниз 10 нулей)
# Среднее temp ПОСЛЕ чистки:     8.11 °C
# Разница из-за 10 строк из 48000: 0.06 °C
#
# Всего 10 битых строк сдвигают среднюю температуру — классическое "среднее врёт".

# %%
# Вторая ловушка: holiday. Наивно: "в праздники трафик выше"?
hol = df_clean['holiday'].notna()
h = df_clean.groupby(hol)['traffic_volume'].agg(['mean','count'])
h.index = ['Обычные часы','Праздничный час']
print(h.round(0))
print()
print('ЛОВУШКА: holiday отмечен только в 1 час суток праздника (полночь),')
print('строк всего', int(h.loc['Праздничный час','count']), '— сравнивать "праздник vs будни" по ним нельзя.')
print('Низкое среднее тут — это эффект полуночи, а не праздника.')
# Out:
#                    mean  count
# Обычные часы     3294.0  40522
# Праздничный час   864.0     53
#
# ЛОВУШКА: holiday отмечен только в 1 час суток праздника (полночь),
# строк всего 53 — сравнивать "праздник vs будни" по ним нельзя.
# Низкое среднее тут — это эффект полуночи, а не праздника.

# %% [markdown]
# **Самое ценное открытие дня:** вывод «в праздники трафик низкий» — артефакт.
# `holiday` проставлен только в один час (00:00), поэтому мы сравниваем не «праздник vs обычный день»,
# а «полночь vs все часы». Правда рядом: чтобы честно мерить эффект праздника, нужно пометить **весь день** праздника, а не один час.

# %% [markdown]
# ## 6. Итог — одно открытие одной фразой
#
# > **На I-94 трафик в будни на 35.6% выше выходных и имеет два острых часа пик (7–8 и 16–17 ч), тогда как в выходные кривая плоская с пиком в полдень — и я проверил, что это не артефакт пропусков (10 битых temp=0 K, выброс дождя 9831 мм и holiday, размеченный лишь на 1 час, я вычистил отдельно).**
#
# *Тридцать секунд: одно число, одна проверка.*
